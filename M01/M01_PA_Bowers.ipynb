# %% [markdown]
# ##### Module 1 Programing Assignment
# ##### Jennifer Bowers 1/20/2026

# %% [markdown]
# ##### 3.1

# %%
60 * 60
# Out:
# 3600

# %% [markdown]
# ##### 3.2

# %%
seconds_per_hour = 3600

# %% [markdown]
# ##### 3.3

# %%
24 * seconds_per_hour
# Out:
# 86400

# %%
hours_in_day = 24

# %% [markdown]
# ##### 3.4

# %%
hours_in_day * seconds_per_hour
# Out:
# 86400

# %%
seconds_per_day = hours_in_day * seconds_per_hour
seconds_per_day
# Out:
# 86400

# %% [markdown]
# ##### 3.5

# %%
seconds_per_day/seconds_per_hour
# Out:
# 24.0

# %% [markdown]
# ##### 3.6

# %%
seconds_per_day//seconds_per_hour
# Out:
# 24

# %% [markdown]
# ##### 4.1

# %%
import os
os.system("cls")

song = """When an eel grabs your arm,
... And it causes great harm,
... That's - a moray!"""
print(song)

words = song.split()

for i, w in enumerate(words):
    if w.startswith('m'):
        words[i] = f"{w.capitalize()}"
song2 = " ".join(words)

print(song2)
# Out:
# When an eel grabs your arm,
# ... And it causes great harm,
# ... That's - a moray!
# When an eel grabs your arm, ... And it causes great harm, ... That's - a Moray!

# %% [markdown]
# ##### 4.2

# %%
# saying = "My kitty cat likes %s, My kitty cat likes %s, My kitty cat fell on his %s And now thinks he's a %s."

new_words = ["roast beef", "ham", "head", "clam"]

print(f"My kitty cat likes {new_words[0]}, \nMy kitty cat likes {new_words[1]}, \nMy kitty cat fell on his {new_words[2]} \nAnd now thinks he's a {new_words[3]}.")
# Out:
# My kitty cat likes roast beef,
# My kitty cat likes ham,
# My kitty cat fell on his head
# And now thinks he's a clam.

# %% [markdown]
# ##### 4.3/4.4

# %%
salutation = "Mr."
name = "John Doe"
product = "extension cord"
verbed = "caught fire"
room = "bathroom"
animals = "cats"
amount = 5.99
percent = 70
spokesman = "Bob Speller"
job_title = "Quality Care Representative"

letter = f'Dear {salutation} {name},\n\nThank you for your letter. We are sorry that our {product} {verbed} in your {room}. Please note that it should never be used in a {room}, especially near any {animals}.\n\nSend us your receipt and {amount} for shipping and handling. We will send you another {product} that, in our tests, is {percent}% less likely to have {verbed}.\n\nThank you for your support.\n\nSincerely,\n{spokesman}\n{job_title}'

print(letter)
# Out:
# Dear Mr. John Doe,
#
# Thank you for your letter. We are sorry that our extension cord caught fire in your bathroom. Please note that it should never be used in a bathroom, especially near any cats.
#
# Send us your receipt and 5.99 for shipping and handling. We will send you another extension cord that, in our tests, is 70% less likely to have caught fire.
#
# Thank you for your support.
#
# Sincerely,
# Bob Speller
# Quality Care Representative

# %% [markdown]
# ##### 4.5

# %%
item = ["duck", "gourd", "spitz"]
contestants = ["Boaty McBoatface", "Horsey McHorseface", "Trainy McTrainface"]

for i, w in enumerate(item):
    prize_announcement = f'The winner for the prize {(item[i])} is {(contestants[i])}!'
    print(prize_announcement)
# Out:
# The winner for the prize duck is Boaty McBoatface!
# The winner for the prize gourd is Horsey McHorseface!
# The winner for the prize spitz is Trainy McTrainface!
